# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("(Upto_Data_Preprocessing)HR_HIRING_ANALYTICS.csv")

data = pd.DataFrame(df)

data
# Out:
#        Sno  Candidate_ID DOJ_Extended  Acceptance_days  Notice_Period  \
# 0        1       2110407          Yes               14             30
# 1        2       2112635           No               18             30
# 2        3       2112838           No                3             45
# 3        4       2115021           No               26             30
# 4        5       2115125          Yes                1            120
# ...    ...           ...          ...              ...            ...
# 8990  8991       3822427           No                4              0
# 8991  8992       3828206          Yes                2              0
# 8992  8993       3834159           No                0              0
# 8993  8994       3835433           No                0             30
# 8994  8995       3836076           No                2              0
#
#      Offered_Band  Expected_CTC_hike_pct  Offered_CTC_hike_pct  CTC_diff_pct  \
# 0              E2                 -20.79                 13.16         33.95
# 1              E2                  50.00                320.00        270.00
# 2              E2                  42.84                 42.84          0.00
# 3              E2                  42.84                 42.84          0.00
# 4              E2                  42.59                 42.59          0.00
# ...           ...                    ...                   ...           ...
# 8990           E1                 191.67                191.67          0.00
# 8991           E1                 150.00                150.00          0.00
# 8992           E2                  35.42                 35.42          0.00
# 8993           E1                  76.92                 53.85        -23.07
# 8994           E1                  45.25                 14.09        -31.16
#
#      Joining_Bonus  ...   Age LOB_Id Domicile_Id  Status Date_of_Interview  \
# 0               No  ...  34.0      1          D6  Joined        2013-01-08
# 1               No  ...  34.0      2          D9  Joined        2013-01-12
# 2               No  ...  27.0      2         D10  Joined        2013-01-25
# 3               No  ...  34.0      2          D3  Joined        2013-01-27
# 4               No  ...  34.0      2         D21  Joined        2013-01-28
# ...            ...  ...   ...    ...         ...     ...               ...
# 8990            No  ...  34.0      1         D21  Joined        2013-08-19
# 8991            No  ...  34.0      4          D9  Joined        2013-08-20
# 8992            No  ...  34.0      2         D18  Joined        2013-08-20
# 8993            No  ...  34.0      2          D2  Joined        2013-08-20
# 8994            No  ...  34.0      2          D3  Joined        2013-08-21
#
#         LOB     Domicile_Name  Location_Name Region_Id Region_Name
# 0       ERS               Goa          Noida        R1       North
# 1     INFRA  Himachal Pradesh        Chennai        R2       South
# 2     INFRA         Jharkhand          Noida        R1       North
# 3     INFRA        Chandigarh          Noida        R1       North
# 4     INFRA           Tripura          Noida        R1       North
# ...     ...               ...            ...       ...         ...
# 8990    ERS           Tripura        Chennai        R2       South
# 8991   BFSI  Himachal Pradesh        Chennai        R2       South
# 8992  INFRA         Rajasthan          Noida        R1       North
# 8993  INFRA             Bihar          Noida        R1       North
# 8994  INFRA        Chandigarh        Chennai        R2       South
#
# [8995 rows x 26 columns]

# %% [markdown]
# # Q1. Analysis of percentage joined of offer released.

# %%
Joined = list(data['Status'].value_counts())[0]
Not_Joined = list(data['Status'].value_counts())[1]

print(f"No of candidates joinged of offer released = {Joined}")
print(f"No of candidates not joinged of offer released = {Not_Joined}")
# Out:
# No of candidates joinged of offer released = 7313
# No of candidates not joinged of offer released = 1682

# %%
Total_candidates = data.shape[0]

print(f"Total No of Candidiates = {Total_candidates}")
# Out:
# Total No of Candidiates = 8995

# %%
joined_pct = (Joined / Total_candidates) * 100
not_joined_pct = (Not_Joined / Total_candidates) * 100

print(f"Percentage joined of offer re")
